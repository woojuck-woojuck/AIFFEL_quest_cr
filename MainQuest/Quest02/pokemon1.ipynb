# %% [markdown]
# Pokemon 'Legendary Pokemon 찾기' 머신 러닝
# =================
# -----------------------------------------
#
# + 아이펠 코어 9기 안진덕
#
# ---------------------------------------
#
# + 의사결정트리, logistic regression, SGD, SVM, 랜덤포레스트 사용
#
# + SGD 방식이 가장 성능이 낮고 의사결정트리가 성능이 가장 좋음.
#
# + Recall(재현율)에 집중. 레전더리 포케몬을 놓치지 않고 가능한 한 많이 탐지하는 것이 중요한 목표.

# %%
#라이브러리 불러오기

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
#데이터 불러오기

csv_path = "Pokemon.csv"
original_data = pd.read_csv(csv_path)

# %%
#포케몬이라는 변수를 만들고 전설급과 일반급으로 나눈다

pokemon = original_data.copy()
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
ordinary = pokemon[pokemon["Legendary"] != True].reset_index(drop=True)

# %%
#결측치 확인

pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
#컬럼 뜯어보기
print(len(pokemon.columns))
pokemon.columns
# Out:
# 13
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#데이터 전처리

pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i)) #이름 숫자 세기
pokemon["long_name"] = pokemon["name_count"] >= 10 #10자 이상 True
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", "")) #알파벳만으로 하기 위해 띄워쓰기 제거
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha()) # 확인

# %%
#알파벳이 아닌거 출력

print(pokemon[pokemon["name_isalpha"] == False].shape)
pokemon[pokemon["name_isalpha"] == False]
# Out:
# (9, 17)
#        #              Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29          Nidoran♀   Poison     NaN    275   55      47       52
# 37    32          Nidoran♂   Poison     NaN    273   46      57       40
# 90    83        Farfetch'd   Normal  Flying    352   52      65       55
# 131  122          Mr. Mime  Psychic   Fairy    460   40      45       65
# 252  233          Porygon2   Normal     NaN    515   85      80       90
# 270  250             Ho-oh     Fire  Flying    680  106     130       90
# 487  439          Mime Jr.  Psychic   Fairy    310   20      25       45
# 525  474         Porygon-Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
# 9개 포케몬 수정

pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon Two")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

pokemon.loc[[34, 37, 90, 131, 252, 270, 487, 525, 794]]
# Out:
#        #           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29      Nidoran X   Poison     NaN    275   55      47       52
# 37    32      Nidoran Y   Poison     NaN    273   46      57       40
# 90    83      Farfetchd   Normal  Flying    352   52      65       55
# 131  122        Mr Mime  Psychic   Fairy    460   40      45       65
# 252  233    Porygon Two   Normal     NaN    515   85      80       90
# 270  250          Ho Oh     Fire  Flying    680  106     130       90
# 487  439        Mime Jr  Psychic   Fairy    310   20      25       45
# 525  474      Porygon Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
#확인

pokemon['Name_nospace'] = pokemon['Name'].str.replace(' ', '', regex=False)
pokemon['name_isalpha'] = pokemon['Name_nospace'].str.isalpha()
pokemon[pokemon["name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %%
#토큰화

import re

def tokenize(name):
    name_split = re.split(r'[ .-]', name)
    tokens = []
    for part_name in name_split:
        a = re.findall('[A-Z][a-z]*', part_name)
        tokens.extend(a)
        
    return np.array(tokens)

all_tokens = list(legendary["Name"].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)

print(len(set(token_set)))
print(token_set)
print(len(token_set))
# Out:
# 65
# ...

# %%
#전설 포케몬들 수식어 상위 10개 뽑아서 보기

from collections import Counter

most_common = Counter(token_set).most_common(10)
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
#전설의 포켓몬 이름에 등장하는 토큰이 포켓몬의 이름에 있는지의 여부를 나타내는 컬럼

for token, _ in most_common:
    pokemon[f"{token}"] = pokemon["Name"].str.contains(token)

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  ...  Forme   Mega  Mewtwo  Kyurem  Deoxys  Hoopa  Latias  \
# ...

# %%
#원핫인코딩
types = list(set(pokemon["Type 1"]))

print(types)

for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)
    
pokemon[[["Type 1", "Type 2"] + types][0]].head()
# Out:
# ['Ice', 'Electric', 'Dragon', 'Fighting', 'Ground', 'Steel', 'Grass', 'Rock', 'Water', 'Poison', 'Normal', 'Psychic', 'Fire', 'Flying', 'Bug', 'Ghost', 'Fairy', 'Dark']
#   Type 1  Type 2    Ice  Electric  Dragon  Fighting  Ground  Steel  Grass  \
# 0  Grass  Poison  False     False   False     False   False  False   True
# 1  Grass  Poison  False     False   False     False   False  False   True
# 2  Grass  Poison  False     False   False     False   False  False   True
# 3  Grass  Poison  False     False   False     False   False  False   True
# 4   Fire     NaN  False     False   False     False   False  False  False
#
#     Rock  Water  Poison  Normal  Psychic   Fire  Flying    Bug  Ghost  Fairy  \
# 0  False  False    True   False    False  False   False  False  False  False
# 1  False  False    True   False    False  False   False  False  False  False
# 2  False  False    True   False    False  False   False  False  False  False
# ...

# %%
#베이스 라인 만들기

from sklearn.model_selection import train_test_split

features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']

target = 'Legendary'

X = original_data[features]
print(X.shape)
y = original_data[target]
print(y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 8)
# (800,)
# (640, 8) (640,)
# (160, 8) (160,)

# %%
#의사 결정 트리 모델(오리지날 데이터)

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model = DecisionTreeClassifier(random_state=25)
print(model)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

confusion_matrix(y_test, y_pred)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# DecisionTreeClassifier(random_state=25)
# [[144   3]
#  [  5   8]]
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.97       147
#         True       0.73      0.62      0.67        13
#
#     accuracy                           0.95       160
#    macro avg       0.85      0.80      0.82       160
# weighted avg       0.95      0.95      0.95       160

# %%
# 피처 엔지니어링 데이터로 학습

features = ['Total', 'HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 
            'name_count','long_name', 'Forme', 'Mega', 'Mewtwo','Deoxys', 'Kyurem', 'Latias', 'Latios',
            'Kyogre', 'Groudon', 'Hoopa','Poison', 'Ground', 'Flying', 'Normal', 'Water', 'Fire',
            'Electric','Rock', 'Dark', 'Fairy', 'Steel', 'Ghost', 'Psychic', 'Ice', 'Bug', 'Grass', 'Dragon', 'Fighting']

len(features)

target = "Legendary"

X = pokemon[features]
print(X.shape)
y=pokemon['Legendary']
print(y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 38)
# (800,)
# (640, 38) (640,)
# (160, 38) (160,)

# %%
#의사 결정 트리

model = DecisionTreeClassifier(random_state=25)
print(model)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

confusion_matrix(y_test, y_pred)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# DecisionTreeClassifier(random_state=25)
# [[141   6]
#  [  1  12]]
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       147
#         True       0.67      0.92      0.77        13
#
#     accuracy                           0.96       160
#    macro avg       0.83      0.94      0.87       160
# weighted avg       0.97      0.96      0.96       160

# %%
#랜덤포레스트

from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(random_state=32) 
random_forest.fit(X_train, y_train) 
y_pred = random_forest.predict(X_test) 

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       147
#         True       0.73      0.85      0.79        13
#
#     accuracy                           0.96       160
#    macro avg       0.86      0.91      0.88       160
# weighted avg       0.97      0.96      0.96       160

# %%
#SVM모델
from sklearn import svm 
svm_model = svm.SVC()
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.99      0.97       147
#         True       0.78      0.54      0.64        13
#
#     accuracy                           0.95       160
#    macro avg       0.87      0.76      0.80       160
# weighted avg       0.95      0.95      0.95       160

# %%
#SGD
from sklearn.linear_model import SGDClassifier 
sgd_model = SGDClassifier() 
sgd_model.fit(X_train, y_train)
y_pred = sgd_model.predict(X_test)
print(classification_report(y_test, y_pred))

print(sgd_model._estimator_type)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.99      0.95       147
#         True       0.33      0.08      0.12        13
#
#     accuracy                           0.91       160
#    macro avg       0.63      0.53      0.54       160
# weighted avg       0.88      0.91      0.89       160
#
# classifier

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression 
logistic_model = LogisticRegression(max_iter=10000) 
logistic_model.fit(X_train, y_train)
y_pred = logistic_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       147
#         True       0.73      0.85      0.79        13
#
#     accuracy                           0.96       160
#    macro avg       0.86      0.91      0.88       160
# weighted avg       0.97      0.96      0.96       160
